# %%
from pathlib import Path
import csv
# Import libraries and dependencies
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Set the file path
#zip_csv = Path('Zip_Zhvi_AllHomes.csv')
hood_csv = Path('Neighborhood_Zhvi_AllHomes.csv')

# %%
#zip_df = pd.read_csv(zip_csv)
hood_df = pd.read_csv(hood_csv)

# %%
#zip_df
hood_df
# Out:
#        RegionID  SizeRank              RegionName    RegionType StateName  \
# 0        274772         0        Northeast Dallas  Neighborhood        TX
# 1        112345         1                Maryvale  Neighborhood        AZ
# 2        192689         2                Paradise  Neighborhood        NV
# 3        270958         3         Upper West Side  Neighborhood        NY
# 4        118208         4       South Los Angeles  Neighborhood        CA
# 5        270957         5         Upper East Side  Neighborhood        NY
# 6        192820         6           Sunrise Manor  Neighborhood        NV
# 7        192796         7           Spring Valley  Neighborhood        NV
# 8        268496         8   Southeast Los Angeles  Neighborhood        CA
# 9        194430         9           East New York  Neighborhood        NY
# 10       112547        10         Paradise Valley  Neighborhood        AZ
# 11       198687        11      Washington Heights  Neighborhood        NY
# ...
