# %%
from pathlib import Path
import csv
# Import libraries and dependencies
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Set the file path
#zip_csv = Path('Zip_Zhvi_AllHomes.csv')
#hood_csv = Path('Neighborhood_Zhvi_AllHomes.csv')
#sale_hood_csv = Path('Sale_Prices_Neighborhood.csv')
sale_state_csv = Path('Sale_Prices_State.csv')

# %%
#zip_df = pd.read_csv(zip_csv)
#hood_df = pd.read_csv(hood_csv)
#sale_hood_df = pd.read_csv(sale_hood_csv)
sale_state_df = pd.read_csv(sale_state_csv)

# %%
#zip_df
#hood_df
#sale_hood_df
sale_state_df.head
# Out:
# <bound method NDFrame.head of     RegionID            RegionName  SizeRank   2008-03   2008-04   2008-05  \
# 0          9            California         1  392500.0  373800.0  351800.0
# 1         54                 Texas         2  139900.0  139300.0  137600.0
# 2         43              New York         3       NaN       NaN       NaN
# 3         14               Florida         4  203400.0  195500.0  189300.0
# 4         21              Illinois         5  204400.0  198400.0  185000.0
# 5         47          Pennsylvania         6  146400.0  144800.0  142500.0
# 6         44                  Ohio         7  110700.0  108700.0  107800.0
# 7         30              Michigan         8   97800.0   94800.0   90200.0
# 8         16               Georgia         9  143200.0  139100.0  135300.0
# 9         36        North Carolina        10  154400.0  151500.0  147500.0
# 10        40            New Jersey        11  328900.0  330000.0  321900.0
# ...
